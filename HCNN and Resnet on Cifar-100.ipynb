# %%
# Import the necessary libraries
import tensorflow as tf
from tensorflow.keras.datasets import cifar100
import numpy as np
import matplotlib.pyplot as plt

# %%
# load the dataset from tensorlfow-keras
(X_train,y_train),(X_test,y_test) = cifar100.load_data()

# %%
# print the shape of train
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
# print the shape of test
X_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
# print the shape of target in train
y_train.shape
# Out:
# (50000, 1)

# %%
# print the shape of target in test
y_test.shape
# Out:
# (10000, 1)

# %%
# print the first value of train
X_train[0]
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [195, 205, 193],
#         [212, 224, 204],
#         [182, 194, 167]],
#
#        [[255, 255, 255],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [170, 176, 150],
#         [161, 168, 130],
#         [146, 154, 113]],
#
#        [[255, 255, 255],
#         [254, 254, 254],
#         [255, 255, 255],
#         ...,
#         [189, 199, 169],
#         [166, 178, 130],
#         [121, 133,  87]],
#
#        ...,
#
#        [[148, 185,  79],
#         [142, 182,  57],
#         [140, 179,  60],
#         ...,
#         [ 30,  17,   1],
#         [ 65,  62,  15],
#         [ 76,  77,  20]],
#
#        [[122, 157,  66],
#         [120, 155,  58],
#         [126, 160,  71],
#         ...,
#         [ 22,  16,   3],
#         [ 97, 112,  56],
#         [141, 161,  87]],
#
#        [[ 87, 122,  41],
#         [ 88, 122,  39],
#         [101, 134,  56],
# ...

# %%
# print the first value of test
X_test[0]
# Out:
# array([[[199, 215, 249],
#         [196, 211, 244],
#         [195, 210, 243],
#         ...,
#         [216, 231, 250],
#         [217, 231, 250],
#         [224, 234, 252]],
#
#        [[197, 210, 239],
#         [195, 208, 238],
#         [195, 210, 240],
#         ...,
#         [231, 243, 250],
#         [233, 243, 250],
#         [241, 245, 253]],
#
#        [[222, 226, 246],
#         [213, 220, 242],
#         [209, 219, 243],
#         ...,
#         [243, 250, 251],
#         [244, 249, 251],
#         [250, 250, 253]],
#
#        ...,
#
#        [[ 72,  73,  99],
#         [ 71,  74, 102],
#         [ 74,  78, 108],
#         ...,
#         [220, 208, 217],
#         [183, 168, 181],
#         [155, 141, 150]],
#
#        [[ 72,  75, 104],
#         [ 76,  81, 111],
#         [ 84,  89, 122],
#         ...,
#         [222, 212, 220],
#         [187, 174, 192],
#         [145, 132, 149]],
#
#        [[ 80,  85, 118],
#         [ 84,  90, 123],
#         [ 85,  92, 127],
# ...

# %%
# print the first value of target -train
y_train[0]
# Out:
# array([19])

# %%
# print the first value of target -test
y_test[0]
# Out:
# array([49])

# %%
# print the value counts of target in train
y_train.value_counts()

# gives error as it is an 'numpy.ndarray' object not a dataframe object
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 y_train.value_counts()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'value_counts'

# %%
# value counts of the numpy array (target of train)
unique_values, counts = np.unique(y_train, return_counts=True)

# Print the unique values and their counts
for value, count in zip(unique_values, counts):
    print(f"{value}: {count}")
# Out:
# 0: 500
# 1: 500
# 2: 500
# 3: 500
# 4: 500
# 5: 500
# 6: 500
# 7: 500
# 8: 500
# 9: 500
# 10: 500
# 11: 500
# 12: 500
# 13: 500
# 14: 500
# 15: 500
# 16: 500
# 17: 500
# 18: 500
# 19: 500
# 20: 500
# 21: 500
# 22: 500
# 23: 500
# 24: 500
# 25: 500
# 26: 500
# 27: 500
# 28: 500
# 29: 500
# 30: 500
# 31: 500
# 32: 500
# 33: 500
# 34: 500
# 35: 500
# 36: 500
# 37: 500
# 38: 500
# 39: 500
# 40: 500
# 41: 500
# 42: 500
# 43: 500
# 44: 500
# 45: 500
# 46: 500
# 47: 500
# 48: 500
# 49: 500
# 50: 500
# 51: 500
# 52: 500
# 53: 500
# 54: 500
# 55: 500
# 56: 500
# 57: 500
# 58: 500
# 59: 500
# 60: 500
# 61: 500
# 62: 500
# 63: 500
# 64: 500
# 65: 500
# 66: 500
# 67: 500
# 68: 500
# 69: 500
# 70: 500
# 71: 500
# 72: 500
# 73: 500
# 74: 500
# 75: 500
# 76: 500
# 77: 500
# 78: 500
# 79: 500
# 80: 500
# 81: 500
# 82: 500
# 83: 500
# 84: 500
# 85: 500
# 86: 500
# 87: 500
# 88: 500
# 89: 500
# 90: 500
# 91: 500
# 92: 500
# 93: 500
# 94: 500
# 95: 500
# 96: 500
# 97: 500
# 98: 500
# 99: 500

# %%
# value counts of the numpy array (target of test)
unique_values, counts = np.unique(y_test, return_counts=True)

# Print the unique values and their counts
for value, count in zip(unique_values, counts):
    print(f"{value}: {count}")
# Out:
# 0: 100
# 1: 100
# 2: 100
# 3: 100
# 4: 100
# 5: 100
# 6: 100
# 7: 100
# 8: 100
# 9: 100
# 10: 100
# 11: 100
# 12: 100
# 13: 100
# 14: 100
# 15: 100
# 16: 100
# 17: 100
# 18: 100
# 19: 100
# 20: 100
# 21: 100
# 22: 100
# 23: 100
# 24: 100
# 25: 100
# 26: 100
# 27: 100
# 28: 100
# 29: 100
# 30: 100
# 31: 100
# 32: 100
# 33: 100
# 34: 100
# 35: 100
# 36: 100
# 37: 100
# 38: 100
# 39: 100
# 40: 100
# 41: 100
# 42: 100
# 43: 100
# 44: 100
# 45: 100
# 46: 100
# 47: 100
# 48: 100
# 49: 100
# 50: 100
# 51: 100
# 52: 100
# 53: 100
# 54: 100
# 55: 100
# 56: 100
# 57: 100
# 58: 100
# 59: 100
# 60: 100
# 61: 100
# 62: 100
# 63: 100
# 64: 100
# 65: 100
# 66: 100
# 67: 100
# 68: 100
# 69: 100
# 70: 100
# 71: 100
# 72: 100
# 73: 100
# 74: 100
# 75: 100
# 76: 100
# 77: 100
# 78: 100
# 79: 100
# 80: 100
# 81: 100
# 82: 100
# 83: 100
# 84: 100
# 85: 100
# 86: 100
# 87: 100
# 88: 100
# 89: 100
# 90: 100
# 91: 100
# 92: 100
# 93: 100
# 94: 100
# 95: 100
# 96: 100
# 97: 100
# 98: 100
# 99: 100

# %%
# Normalize pixel values to be between 0 and 1
X_train, X_test = X_train / 255.0, X_test / 255.0

# %%
# print the first value of train
X_train[0]
# Out:
# array([[[1.        , 1.        , 1.        ],
#         [1.        , 1.        , 1.        ],
#         [1.        , 1.        , 1.        ],
#         ...,
#         [0.76470588, 0.80392157, 0.75686275],
#         [0.83137255, 0.87843137, 0.8       ],
#         [0.71372549, 0.76078431, 0.65490196]],
#
#        [[1.        , 1.        , 1.        ],
#         [0.99607843, 0.99607843, 0.99607843],
#         [0.99607843, 0.99607843, 0.99607843],
#         ...,
#         [0.66666667, 0.69019608, 0.58823529],
#         [0.63137255, 0.65882353, 0.50980392],
#         [0.57254902, 0.60392157, 0.44313725]],
#
#        [[1.        , 1.        , 1.        ],
#         [0.99607843, 0.99607843, 0.99607843],
#         [1.        , 1.        , 1.        ],
#         ...,
#         [0.74117647, 0.78039216, 0.6627451 ],
#         [0.65098039, 0.69803922, 0.50980392],
#         [0.4745098 , 0.52156863, 0.34117647]],
#
#        ...,
#
#        [[0.58039216, 0.7254902 , 0.30980392],
# ...

# %%
# print the first value of test
X_test[0]
# Out:
# array([[[0.78039216, 0.84313725, 0.97647059],
#         [0.76862745, 0.82745098, 0.95686275],
#         [0.76470588, 0.82352941, 0.95294118],
#         ...,
#         [0.84705882, 0.90588235, 0.98039216],
#         [0.85098039, 0.90588235, 0.98039216],
#         [0.87843137, 0.91764706, 0.98823529]],
#
#        [[0.77254902, 0.82352941, 0.9372549 ],
#         [0.76470588, 0.81568627, 0.93333333],
#         [0.76470588, 0.82352941, 0.94117647],
#         ...,
#         [0.90588235, 0.95294118, 0.98039216],
#         [0.91372549, 0.95294118, 0.98039216],
#         [0.94509804, 0.96078431, 0.99215686]],
#
#        [[0.87058824, 0.88627451, 0.96470588],
#         [0.83529412, 0.8627451 , 0.94901961],
#         [0.81960784, 0.85882353, 0.95294118],
#         ...,
#         [0.95294118, 0.98039216, 0.98431373],
#         [0.95686275, 0.97647059, 0.98431373],
#         [0.98039216, 0.98039216, 0.99215686]],
#
#        ...,
#
#        [[0.28235294, 0.28627451, 0.38823529],
# ...

# %%
# print the first 25 values of y_train
for i in range(25):
    print(y_train[i],end=", ")
# Out:
# [19], [29], [0], [11], [1], [86], [90], [28], [23], [31], [39], [96], [82], [17], [71], [39], [8], [97], [80], [71], [74], [59], [70], [87], [59],

# %%
# define a list representing the lables of first 25 values of y_train
class_names = ['cattle', 'dinosaur', 'apple', 'boy','aquarium_fish', 'telephone', 'train','cup','cloud','elephant','Computer Keyboard',
               'willow_tree','sun flower','trees','sea','Keyboard','bicycle','wolf',"squirrel",'sea',"shrew","pine_tree","rose","television","pine_tree"]

# plot the first 25 pictures in y_train aling with the labels
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i])
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[i])
plt.show()

# %%
# 1. Build a converntional CNN Model

# %%
# model definition
model = tf.keras.models.Sequential()


# In model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
# 32 is the number of filters (also known as kernels or channels) in the convolutional layer.
# (3,3) specifies the size of each filter. Each filter is a 3x3 matrix.

model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
#droupout(.1)
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
# MaxPooling is a downsampling operation commonly used in convolutional neural networks.
# (2, 2) defines the size of the pooling window. In this case, it's a 2x2 window.

model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu'))
#frpout(.2)
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu'))

# transforms the input into a one-dimensional array without modifying the actual data.
model.add(tf.keras.layers.Flatten())

model.add(tf.keras.layers.Dense(128, activation='relu'))

# output layer
model.add(tf.keras.layers.Dense(100, activation='softmax'))

# %%
# When using a softmax activation in the output layer, you typically set from_logits=False. 
# This is because the softmax activation function will normalize the raw logits into probabilities, 
# and you want the cross-entropy loss to be calculated directly from these probabilities.

# On the other hand, when using a sigmoid activation in the output layer, you would often set from_logits=True. 
# In this case, the model's output would be raw logits, and the cross-entropy loss expects these unnormalized scores. 
# The sigmoid activation function is then applied during the calculation of the loss.

# %% [markdown]
# ![image.png](attachment:0133fcc8-b717-4daf-a17c-b156bb09cf61.png)

# %%
# for softmax activation in the output layer
# model.compile(optimizer='adam',
#               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#               metrics=['accuracy'])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),  # Changed from_logits to False
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=100, 
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 40s 25ms/step - loss: 3.8273 - accuracy: 0.1139 - val_loss: 3.3378 - val_accuracy: 0.2010
# Epoch 2/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 3.1025 - accuracy: 0.2420 - val_loss: 2.9746 - val_accuracy: 0.2710
# Epoch 3/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 2.7900 - accuracy: 0.3009 - val_loss: 2.8166 - val_accuracy: 0.3013
# Epoch 4/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 2.5908 - accuracy: 0.3422 - val_loss: 2.7383 - val_accuracy: 0.3220
# Epoch 5/100
# 1563/1563 [==============================] - 38s 24ms/step - loss: 2.4478 - accuracy: 0.3700 - val_loss: 2.6255 - val_accuracy: 0.3379
# Epoch 6/100
# 1563/1563 [==============================] - 38s 24ms/step - loss: 2.3249 - accuracy: 0.3956 - val_loss: 2.5968 - val_accuracy: 0.3536
# Epoch 7/100
# ...

# %%
# plot the performance of the model
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# plot accuracy of test and train
test_loss, test_acc = model.evaluate(X_test,  y_test, verbose=2)
# Out:
# 313/313 - 3s - loss: 12.0852 - accuracy: 0.2919 - 3s/epoch - 10ms/step

# %% [markdown]
# ##### loc parameter in plt.legend
#
# ![image.png](attachment:5ad4f182-c00a-4af0-92a0-8296ccd1efac.png)

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.ylim([0, 15])
plt.legend(loc='best')


test_loss, test_acc = model.evaluate(X_test,  y_test, verbose=2)
# Out:
# 313/313 - 4s - loss: 12.0852 - accuracy: 0.2919 - 4s/epoch - 11ms/step

# %% [markdown]
# ## from the performance report of the model, we can see that the model is clearly overfitting as the train accuracy is high (87.88%) and the test accuracy is ver low (29.19%). so we can try out some of the techniques like Resnet and Hierarchical DCNN

# %%
# Build a Resnet Neural Network

# %%
# Code for Identity Block
def identity_block(x, filter):
    # copy tensor to variable called x_skip
    x_skip = x
    # Layer 1
    x = tf.keras.layers.Conv2D(filter, (3,3), padding='same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation('relu')(x)
    # Layer 2
    #x = tf.keras.layers.Conv2D(filter, (3,3), padding='same')(x)
    #x = tf.keras.layers.BatchNormalization(axis=3)(x)
    # Add Residue
    x = tf.keras.layers.Add()([x, x_skip])     
    x = tf.keras.layers.Activation('relu')(x)
    return x

# %%
# Code for Convolutional Block
def convolutional_block(x, filter):
    # copy tensor to variable called x_skip
    x_skip = x
    # Layer 1
    x = tf.keras.layers.Conv2D(filter, (3,3), padding='same', strides=(2,2))(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation('relu')(x)
    # Layer 2
#    x = tf.keras.layers.Conv2D(filter, (3,3), padding='same')(x)
 #   x = tf.keras.layers.BatchNormalization(axis=3)(x)
    # Processing Residue with conv(1,1)
    x_skip = tf.keras.layers.Conv2D(filter, (1,1), strides=(2,2))(x_skip)
    # Add Residue
    x = tf.keras.layers.Add()([x, x_skip])     
    x = tf.keras.layers.Activation('relu')(x)
    return x

# %%
# Code for Resnet Model

def ResNet34(shape=(32, 32, 3), classes=100):
    # Step 1 (Setup Input Layer)
    x_input = tf.keras.layers.Input(shape)
    x = tf.keras.layers.ZeroPadding2D((3, 3))(x_input)

    # Step 2 (Initial Conv layer along with maxPool)
    x = tf.keras.layers.Conv2D(64, kernel_size=7, strides=2, padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')(x)
    
    # Define size of sub-blocks and initial filter size
    block_layers = [3, 4, 6, 3]
    filter_size = 64
    
    # Step 3 Add the Resnet Blocks
    for i in range(4):
        if i == 0:
            # For sub-block 1 Residual/Convolutional block not needed
            for j in range(block_layers[i]):
                x = identity_block(x, filter_size)
        else:
            # One Residual/Convolutional Block followed by Identity blocks
            # The filter size will go on increasing by a factor of 2
            filter_size = filter_size*2
            x = convolutional_block(x, filter_size)
            for j in range(block_layers[i] - 1):
                x = identity_block(x, filter_size)

    # Step 4 End Dense Network
    x = tf.keras.layers.AveragePooling2D((2, 2), padding='same')(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(512, activation='relu')(x)
    x = tf.keras.layers.Dense(classes, activation='softmax')(x)  # Change the number of classes here
    model = tf.keras.models.Model(inputs=x_input, outputs=x, name="ResNet34")
    return model

# %%
# Create the ResNet model with classes=100
resnet_model = ResNet34(classes=100)

# %%
# compile the model
resnet_model.compile(optimizer = 'adam', loss='sparse_categorical_crossentropy', metrics = ['accuracy'])

# print the summary of the model
resnet_model.summary()
# Out:
# Model: "ResNet34"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  zero_padding2d_1 (ZeroPadding2  (None, 38, 38, 3)   0           ['input_2[0][0]']
#  D)
#
#  conv2d_6 (Conv2D)              (None, 19, 19, 64)   9472        ['zero_padding2d_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 19, 19, 64)   0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 10, 10, 64)  0           ['activation_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 10, 10, 64)   36928       ['max_pooling2d_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 10, 10, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
# ...

# %%
# define the function to visualise the performance of the model
def visualize_results(history):
  figure = plt.figure(figsize=(15, 10))
  plt.subplot(211)
  plt.title('Cross Entropy Loss')
  plt.plot(history.history['loss'], color='blue', label='train')
  plt.plot(history.history['val_loss'], color='orange', label='test')
  # plot accuracy
  plt.subplot(212)
  plt.title('Classification Accuracy')
  plt.plot(history.history['accuracy'], color='blue', label='train')
  plt.plot(history.history['val_accuracy'], color='orange', label='test')

# %%
# fit the model
history = resnet_model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs = 15)

#visualise the performance of the model
visualize_results(history)
# Out:
# Epoch 1/15
# 1563/1563 [==============================] - 1628s 1s/step - loss: 4.1879 - accuracy: 0.0476 - val_loss: 4.3942 - val_accuracy: 0.0509
# Epoch 2/15
# 1563/1563 [==============================] - 1636s 1s/step - loss: 3.7611 - accuracy: 0.1013 - val_loss: 3.6423 - val_accuracy: 0.1265
# Epoch 3/15
# 1563/1563 [==============================] - 1623s 1s/step - loss: 3.4227 - accuracy: 0.1615 - val_loss: 3.4057 - val_accuracy: 0.1734
# Epoch 4/15
# 1563/1563 [==============================] - 1612s 1s/step - loss: 3.1209 - accuracy: 0.2196 - val_loss: 3.3720 - val_accuracy: 0.1924
# Epoch 5/15
# 1563/1563 [==============================] - 1632s 1s/step - loss: 2.8525 - accuracy: 0.2741 - val_loss: 4.0314 - val_accuracy: 0.1390
# Epoch 6/15
# 1563/1563 [==============================] - 1622s 1s/step - loss: 2.6076 - accuracy: 0.3227 - val_loss: 3.4853 - val_accuracy: 0.2193
# Epoch 7/15
# ...

# %%
# Build a Hierarchical DCNN

# %%
from keras import optimizers
from keras.layers import Input, Conv2D, Dropout, MaxPooling2D, Flatten, Dense
from keras.models import Model

in_layer = Input(shape=(32, 32, 3), dtype='float32', name='main_input')

net = Conv2D(16, 3, strides=1, padding='same', activation='elu')(in_layer)
#net = Conv2D(384, 3, strides=1, padding='same', activation='elu')(in_layer)
net = MaxPooling2D((2, 2), padding='valid')(net)

#net = Conv2D(384, 1, strides=1, padding='same', activation='elu')(net)
#net = Conv2D(384, 2, strides=1, padding='same', activation='elu')(net)
#net = Conv2D(640, 2, strides=1, padding='same', activation='elu')(net)
#net = Conv2D(640, 2, strides=1, padding='same', activation='elu')(net)
#net = Dropout(.2)(net)

net = Conv2D(16, 1, strides=1, padding='same', activation='elu')(net)
net = Conv2D(16, 2, strides=1, padding='same', activation='elu')(net)
net = Conv2D(32, 2, strides=1, padding='same', activation='elu')(net)
net = Conv2D(32, 2, strides=1, padding='same', activation='elu')(net)
net = Dropout(.2)(net)
net = MaxPooling2D((2, 2), padding='valid')(net)

#net = Conv2D(640, 1, strides=1, padding='same', activation='elu')(net)
#net = Conv2D(768, 2, strides=1, padding='same', activation='elu')(net)
#net = Conv2D(768, 2, strides=1, padding='same', activation='elu')(net)
#net = Conv2D(768, 2, strides=1, padding='same', activation='elu')(net)
#net = Dropout(.3)(net)
#net = MaxPooling2D((2, 2), padding='valid')(net)

net = Conv2D(32, 1, strides=1, padding='same', activation='elu')(net)
net = Conv2D(64, 2, strides=1, padding='same', activation='elu')(net)
net = Conv2D(64, 2, strides=1, padding='same', activation='elu')(net)
net = Conv2D(64, 2, strides=1, padding='same', activation='elu')(net)
net = Dropout(.2)(net)
net = MaxPooling2D((2, 2), padding='valid')(net)

#net = Conv2D(768, 1, strides=1, padding='same', activation='elu')(net)
#net = Conv2D(896, 2, strides=1, padding='same', activation='elu')(net)
#net = Conv2D(896, 2, strides=1, padding='same', activation='elu')(net)
#net = Dropout(.4)(net)
#net = MaxPooling2D((2, 2), padding='valid')(net)

#net = Conv2D(896, 3, strides=1, padding='same', activation='elu')(net)
#net = Conv2D(1024, 2, strides=1, padding='same', activation='elu')(net)
#net = Conv2D(1024, 2, strides=1, padding='same', activation='elu')(net)
#net = Dropout(.5)(net)
#net = MaxPooling2D((2, 2), padding='valid')(net)

#net = Conv2D(1024, 1, strides=1, padding='same', activation='elu')(net)
#net = Conv2D(1152, 2, strides=1, padding='same', activation='elu')(net)
#net = Dropout(.6)(net)
#net = MaxPooling2D((2, 2), padding='same')(net)

net = Flatten()(net)
#net = Dense(1152, activation='elu')(net)
net = Dense(128, activation='elu')(net)
net = Dense(100, activation='softmax')(net)

# %%
# compile the model
model = Model(inputs=in_layer,outputs=net)
sgd_coarse = optimizers.SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer= sgd_coarse, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
tbCallBack = tf.keras.callbacks.TensorBoard(log_dir='./data/', histogram_freq=0, write_graph=True, write_images=True)

# %%
batch = 64
index= 0
step = 5
stop = 30

# %%
def one_hot(y):
    n_values = np.max(y) + 1
    y_new = np.eye(n_values)[y[:,0]]
    return y_new

# %%
y_train_new=one_hot(y_train)
y_test_new=one_hot(y_test)
print(np.shape(y_train_new))
# Out:
# (50000, 100)

# %%
while index < stop:
    model.fit(X_train, y_train_new, batch_size=batch, initial_epoch=index, epochs=index+step, validation_data=(X_test, y_test_new), callbacks=[tbCallBack])
    index += step
    model.save_weights('data/models'+str(index))
save_index = index
# Out:
# Epoch 1/5
# 782/782 [==============================] - 57s 72ms/step - loss: 3.9215 - accuracy: 0.1040 - val_loss: 3.6180 - val_accuracy: 0.1610
# Epoch 2/5
# 782/782 [==============================] - 60s 77ms/step - loss: 3.1169 - accuracy: 0.2377 - val_loss: 3.3342 - val_accuracy: 0.2154
# Epoch 3/5
# 782/782 [==============================] - 62s 79ms/step - loss: 2.7430 - accuracy: 0.3085 - val_loss: 2.9886 - val_accuracy: 0.2856
# Epoch 4/5
# 782/782 [==============================] - 59s 76ms/step - loss: 2.5018 - accuracy: 0.3604 - val_loss: 2.5874 - val_accuracy: 0.3552
# Epoch 5/5
# 782/782 [==============================] - 57s 73ms/step - loss: 2.3354 - accuracy: 0.3935 - val_loss: 2.8503 - val_accuracy: 0.3434
# Epoch 6/10
# 782/782 [==============================] - 58s 74ms/step - loss: 2.2069 - accuracy: 0.4211 - val_loss: 2.5303 - val_accuracy: 0.3796
# Epoch 7/10
# ...

# %%
# Load Most Recent Model
sgd_fine = optimizers.SGD(learning_rate=0.001, decay=1e-6, momentum=0.9, nesterov=True)
for i in range(len(model.layers)):
    model.layers[i].trainable=False

# %% [markdown]
# # ............................................................. Thank You .............................................................
